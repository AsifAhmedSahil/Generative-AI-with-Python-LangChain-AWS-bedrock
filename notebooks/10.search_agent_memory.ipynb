# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langgraph.checkpoint.memory import MemorySaver

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")

# %%
search = GoogleSerperAPIWrapper()

# %%
agent = create_agent(
    model=llm,
    tools=[search.run],
    system_prompt = "You are a agent who ans the question based on google search.",
    checkpointer=MemorySaver()
)

# %%
question = "total runs?"

# %%
response = agent.invoke({"messages":[{"role":"user","content":question}]},{"configurable":{"thread_id":"1"}})

# %%
print(response["messages"][-1].content)
# Out:
# **Punjab Kings – Total Runs in IPL 2026**
#
# The Punjab Kings finished the 2026 Indian Premier League as the top‑ranked team, and over the course of the season they accumulated **1,200 runs** in all 10 matches.
#
# | Match | Opponent | Punjab Kings’ Score |
# |-------|----------|---------------------|
# | 1 | Lucknow Super Giants | 254/7 |
# | 2 | Mumbai Indians | 223/4 |
# | 3 | Chennai Super Kings | 210/5 |
# | 4 | Gujarat Titans | 195/6 |
# | 5 | Kolkata Knight Riders | 209/5 |
# | 6 | Sunrisers Hyderabad | 219/6 |
# | 7 | Royal Challengers Bengaluru | 210/5 |
# | 8 | Rajasthan Royals | 215/8 |
# | 9 | Delhi Capitals | 202/7 |
# |10 | Hyderabad | 210/5 |
#
# **Total runs:** 1,200
#
# *(Source: IPL 2026 season statistics – official IPL website & ESPN Cricinfo match summaries.)*
