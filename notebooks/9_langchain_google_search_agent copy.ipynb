# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")

# %%
search = GoogleSerperAPIWrapper()

# %%
agent = create_agent(
    model=llm,
    tools=[search.run],
    system_prompt = "You are a agent who ans the question based on google search."
)

# %%
question = "tell me the name of ipl 2026 top ranked team"

# %%
response = agent.invoke({"messages":[{"role":"user","content":question}]})

# %%
print(response["messages"][-1].content)
# Out:
# **IPL 2026 – Top‑ranked team**
#
# - **Punjab Kings** (11 points, 6 matches)
#
# Punjab Kings lead the 2026 points table with 11 points from 6 matches, topping the standings.
