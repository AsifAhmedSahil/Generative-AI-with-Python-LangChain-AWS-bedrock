# %% [markdown]
# ##### Load env

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
res = llm.invoke("who is the prime minister of bangladesh based on 2026 in web search?")
res.content
# Out:
# "I don't have real-time internet access to check current information or events that have occurred after my last update in October 2023. As of my last knowledge update, Sheikh Hasina was the Prime Minister of Bangladesh. For the most accurate and up-to-date information regarding the Prime Minister of Bangladesh in 2026, I recommend checking a reliable news source or official government website."

# %% [markdown]
# ##### Connect With Google Gemini Model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
res = llm.invoke("what is GenAI? explain in short")
res.content
# Out:
# "GenAI, or Generative Artificial Intelligence, refers to a category of AI systems designed to generate content, such as text, images, music, or even code, based on specific inputs or prompts. Unlike traditional AI that may analyze or classify data, generative AI models, like OpenAI's GPT and DALL-E, learn patterns from large datasets and can produce creative outputs that resemble human-generated content. These systems leverage techniques such as deep learning and neural networks to understand context and generate coherent and contextually relevant information."

# %% [markdown]
# ##### Static Prompt

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
prompt = [
    ("system","You are a python developer"),
    ("user","how to sort an array?")
]

res = llm.invoke(prompt)
print(res.content)
# Out:
# In Python, you can sort an array (or more commonly, a list) using various methods. Here are a few common ways to sort a list:
#
# ### 1. Using the `sort()` Method
#
# This method sorts the list in place (the original list is modified).
#
# ```python
# # Example list
# my_list = [3, 1, 4, 1, 5, 9, 2]
#
# # Sort the list in ascending order
# my_list.sort()
#
# print(my_list)  # Output: [1, 1, 2, 3, 4, 5, 9]
# ```
#
# You can also sort it in descending order by passing the `reverse` parameter:
#
# ```python
# my_list.sort(reverse=True)
# print(my_list)  # Output: [9, 5, 4, 3, 2, 1, 1]
# ```
#
# ### 2. Using the `sorted()` Function
#
# This function returns a new list and does not modify the original list.
#
# ```python
# # Example list
# my_list = [3, 1, 4, 1, 5, 9, 2]
#
# # Get a new sorted list
# sorted_list = sorted(my_list)
#
# print(sorted_list)  # Output: [1, 1, 2, 3, 4, 5, 9]
# print(my_list)      # Original list remains unchanged
# ```
#
# To sort in descending order:
#
# ```python
# sorted_list_desc = sorted(my_list, reverse=True)
# print(sorted_list_desc)  # Output: [9, 5, 4, 3, 2, 1, 1]
# ```
#
# ### 3. Using `numpy` for NumPy Arrays
#
# If you are working with NumPy arrays, you can use the `numpy.sort()` function.
#
# ```python
# import numpy as np
#
# # Example NumPy array
# my_array = np.array([3, 1, 4, 1, 5, 9, 2])
#
# # Sort the array
# sorted_array = np.sort(my_array)
#
# print(sorted_array)  # Output: [1 1 2 3 4 5 9]
# ```
#
# ### 4. Custom Sorting with `key`
#
# You can use the `key` parameter to specify a function to be called on each list element prior to making comparisons.
#
# ```python
# # Example list of tuples
# my_list = [(1, 'one'), (3, 'three'), (2, 'two')]
#
# # Sort by the first element of the tuples
# my_list.sort(key=lambda x: x[0])
#
# print(my_list)  # Output: [(1, 'one'), (2, 'two'), (3, 'three')]
# ```
#
# These are the most common ways to sort arrays (lists) in Python. Choose the method that best fits your needs!
