# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
documents = [
    "Machine learning is a subset of artificial intelligence",
    "Deep learning uses neural networks with multiple layers",
    "Python is a programming language popular for data science",
    "India won the cricket world cup in 2011",
    "AI models can understand and generate human language"
]

# %%
from langchain_openai import OpenAIEmbeddings

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
vector = embeddings.embed_documents(documents)
print(len(vector[0]))
# Out:
# 3072

# %% [markdown]
# ### Store Vector Database in Vector DB - ChromaDB

# %%
from langchain_chroma import Chroma

# %%
vector_store = Chroma.from_texts(
    texts=documents,
    embedding=embeddings,
    persist_directory="./vector_db"
)

# %%
query = "Data science"
result = vector_store.similarity_search(query=query,k=2)
result
# Out:
# [Document(id='4d950483-0cb2-4c12-b3a3-3668779ee28e', metadata={}, page_content='Python is a programming language popular for data science'),
#  Document(id='21af527a-a5c6-490e-a587-35353e17f7a2', metadata={}, page_content='Machine learning is a subset of artificial intelligence')]
