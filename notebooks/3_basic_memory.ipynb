# %% [markdown]
# ### Manage History

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
history = []

while True:
    query = input("user: ")
    if query.lower() in ["exit","bye","quit"]:
        print("Good Bye")
        break 
    history.append({"role":"user","content":query})
    print("User",query)




    res = llm.invoke(history)
    history.append({"role":"ai", "content":res.content})
    print("AI: ",res.content, "\n")
# Out:
# User hello
# AI:  Hello! How can I assist you today?
#
# User my name is asif
# AI:  Nice to meet you, Asif! How can I help you today?
#
# User what is my name?
# AI:  Your name is Asif. How can I assist you further?
#
# User who is the pm on bd?
# AI:  As of my last knowledge update in October 2023, Sheikh Hasina is the Prime Minister of Bangladesh. She has been in office since January 6, 2009. Please verify with current sources, as political situations can change.
#
# User what is her age?
# AI:  Sheikh Hasina was born on September 28, 1947. As of October 2023, she would be 76 years old.
#
# Good Bye
